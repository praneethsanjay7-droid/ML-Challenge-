# %%
import pandas as pd 

ground_truth = pd.read_csv("student_resource/dataset/train/train_ground_truth.tsv",
    sep="\t")
s1 = pd.read_csv("student_resource/dataset/train/train_source1.tsv",
    sep="\t")
s2=pd.read_csv("student_resource/dataset/train/train_source2.tsv",
    sep="\t")
s3=pd.read_csv("student_resource/dataset/train/train_source3.tsv",
    sep="\t")

# %%
ground_truth.shape
# Out:
# (2206821, 2)

# %%
s1.shape
# Out:
# (2206821, 4)

# %%
s2.shape
# Out:
# (5034616, 4)

# %%
s3.shape
# Out:
# (5285603, 4)

# %%
ground_truth.head()
# Out:
#   source1_entity_id                                 matched_entity_ids
# 0         S1-965667  S2-681193310,S2-743505751,S3-775321672,S3-1129...
# 1       S1-55344266  S2-249013014,S2-197070651,S3-478195123,S3-3843...
# 2      S1-343815751             S2-790675320,S2-479876582,S3-878454467
# 3      S1-656753428              S2-153058913,S2-24659151,S3-679606215
# 4      S1-102811957  S2-478959098,S2-553508714,S2-625774905,S3-7280...

# %%
s1.head()
# Out:
#       entity_id            business_name  \
# 0  S1-925783039      Orelee's Barbershop
# 1  S1-773889195              Prime Money
# 2  S1-377745466            B+ Retail Inc
# 3  S1-133037285            Christ Chapel
# 4  S1-755362802  Prabhav Business Center
#
#                                     business_address country
# 0             1795 Westchester Drive, High Point, NC      US
# 1                    17560 Ellis Road, Tahlequah, OK      US
# 2                1712 Montebello Avenue, Phoenix, AZ      US
# 3  2100 Cameron Drive, Unit APARTMENT G, Dundalk, MD      US
# 4  797, Lake Town Block A, Kolkata, Howrah, West ...   India

# %%
s1['country'].value_counts()
# Out:
# country
# US       1323633
# India     883188
# Name: count, dtype: int64

# %%
s2.head()
# Out:
#       entity_id                    business_name  \
# 0  S2-166376419  राम मार्केटिंग प्राइवेट लिमिटेड
# 1  S2-764573417     -- Holloway Peak Inc Seafood
# 2  S2-639257739         आदित्य प्रॉपर्टीज एलएलपी
# 3  S2-163963287                       Summit Inc
# 4   S2-49942811     Delta Tetlecommunication Inc
#
#                                    business_address country
# 0      KH NO. -570/13, NEW DELHI, WEST DELHI, Delhi   India
# 1                         105 ELM ST, MORGANTON, NC      US
# 2  G-3/571, GULMOHAR COLONY, BHOPAL, Madhya Pradesh   India
# 3             GREENSBORO, NC, 19 1/2 STARDUST TRAIL      US
# 4                   914 PIERPONT AVE, CLEVELAND, OH      US

# %%
s3.head()
# Out:
#       entity_id                                business_name  \
# 0  S3-202863386                           wilfordhancock.com
# 1  S3-859268022  International South Consultants Private Ltd
# 2   S3-22467283                  LLC Moncada Léarning Center
# 3  S3-671162755                               Moyna's Coffee
# 4  S3-960981775                 Pvt. EFS Print Ventures Ltd.
#
#                                     business_address country
# 0                        Mack Rd, Haltom City, Texas      US
# 1                                                NaN   India
# 2                    5780 Fawn Ct, Fort Worth, Texas      US
# 3       1 Ivanhoe Ave, PO Box 6009, Cincinnati, Ohio      US
# 4  Door No 183, 41St Cross, 22Nd Main 9Th Block J...   India

# %%
s1.isnull().sum()
# Out:
# entity_id           0
# business_name       0
# business_address    0
# country             0
# dtype: int64

# %%
s2.isnull().sum()
# Out:
# entity_id                0
# business_name            2
# business_address    168967
# country                  0
# dtype: int64

# %%
s3.isnull().sum()
# Out:
# entity_id                0
# business_name           13
# business_address    175916
# country                  0
# dtype: int64

# %%
ground_truth.isnull().sum()
# Out:
# source1_entity_id          0
# matched_entity_ids    123247
# dtype: int64

# %%
s1.columns
# Out:
# Index(['entity_id', 'business_name', 'business_address', 'country'], dtype='object')

# %%
s1['business_name'].value_counts()
# Out:
# business_name
# Primary Care Group                      253
# Ear Nose & Throat Group                 251
# Pediatric Group                         222
# Womens Health Group                     220
# Physical Therapy Group                  218
#                                        ...
# Columbus Baptist Pioneer Association      1
# ICH Development Pvt Ltd                   1
# Star Secure Crescent                      1
# Espinoza Capital                          1
# Abc Sangh Limited                         1
# Name: count, Length: 1539229, dtype: int64

# %%
s2['business_name'].value_counts()
# Out:
# business_name
# Primary Care                                   320
# Physical Therapy                               307
# Womens Health                                  297
# Urgent Care                                    297
# Behavioral Health                              296
#                                               ...
# Private Services Gujar Informatics Ltd           1
# SMART ENTERPRISES  LP CENTER                     1
# Odele Hairston Coastal Montreal Group Group      1
# Sh Homes (India)                                 1
# CONTINENTAL CDT PC                               1
# Name: count, Length: 4402008, dtype: int64

# %%
s3['business_name'].value_counts()
# Out:
# business_name
# Primary Care                                  421
# Physical Therapy                              399
# Pediatric Dental                              393
# Womens Health                                 379
# Urgent Care                                   377
#                                              ...
# diistidewater.com                               1
# Indore Capital Enterprises Private Limited      1
# Legacy Network Alliance Ltd                     1
# southenergy.com                                 1
# The Trusted Defense Products Inc                1
# Name: count, Length: 4651608, dtype: int64

# %%
s1['business_address'].value_counts()
# Out:
# business_address
# 108 Norle Street, College Twp, PA                                                                                14
# 1921 Willow Park Drive, Fort Worth, TX                                                                           13
# 55, Lavkush Vihar, Singhpur, Kachhar Bithoor Road, Kalyanpur, Kanpur Nagar, Uttar Pradesh                        13
# 104 Roadrunner Circle, Elephant Butte, NM                                                                        13
# 43 Franklin Street, Delaware, OH                                                                                 13
#                                                                                                                  ..
# Galleria Dlf-Iv, The Belaire, Golf Course Road, Dlf City, Gurgaon, Haryana, Ble-272                               1
# 5409 Riverdale Road, Unit E3, Riverdale, MD                                                                       1
# ...

# %%
s2['business_address'].value_counts()
# Out:
# business_address
# 842 38, CALEDONAI TOWNSHIP, WI                                                                       18
# 1948 WEAVER FOREST WAY, MORRISVILLE, NC                                                              18
# 66 FRANK EDGE, ALTO, TX                                                                              17
# 302 REGENCY CT, AMES, IA                                                                             16
# G-58/1, BENSON CROSS ROAD, BANGALORE., Karnataka                                                     16
#                                                                                                      ..
# 5165 CAPLINGER RD, SALEM, OR                                                                          1
# Maharashtra, BLOCK E-447 B/19, SHANTA JADHAV CHAL SAHAKAR NGR JIIVDANI CROSS RD VIRAR EAST, THANE     1
# 72 MARSDEN RD, CONSTANTIA, NY                                                                         1
# ...

# %%
s3['business_address'].value_counts()
# Out:
# business_address
# Ground Floor, Bangalore, KA                                                    29
# Floor, Mumbai, MH                                                              26
# 18, Kolkata, Howrah, WB                                                        26
# 303, Mumbai, MH                                                                25
# 12, Ahmedabad, GJ                                                              23
#                                                                                ..
# 508, Savitri Cinema Complex, Greater Kailash-ii, New Delhi, South Delhi, DL     1
# 706 East River Rd, Mathews County, Virginia                                     1
# 293 Valleyview, Bldg Building, Coalville, Utah                                  1
# 07941 Pioneer Road, Wyoming, Minnesota                                          1
# Portland, Maine, Forest Park                                                    1
# Name: count, Length: 4632764, dtype: int64

# %%
s1['country'].value_counts()
# Out:
# country
# US       1323633
# India     883188
# Name: count, dtype: int64

# %%
s2['country'].value_counts()
# Out:
# country
# US       3016817
# India    2017799
# Name: count, dtype: int64

# %%
s3['country'].value_counts()
# Out:
# country
# US       3170056
# India    2115547
# Name: count, dtype: int64
